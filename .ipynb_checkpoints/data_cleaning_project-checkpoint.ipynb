# %% [markdown]
# **PROJECT TITLE: CLEANING MESSY DATA**
#
# **DATA SOURCE: https://t.co/q1nWWBmlFH**
#
# **CREDIT: EYO EYO, PHD**
#
# **LINK: https://x.com/Eyowhite3/status/1814632317702267081**
#
# **PARTICIPANT: Aniekan Charles Ekanem**
#
# **Designation: Data Analyst**

# %% [markdown]
# This is a project practice for cleaning messy data and making it presentable and ready for analysis
#
# If data is said to be messy, it means it's not yet ripe for further analysis for making an informed business decision.  The data could contain, inconsistencies, wrong empty cells, etc.  Hence it needs to be cleaned first before it can be used for any other purpose.

# %%
# Importing libraries

import numpy as np
import pandas as pd
import csv

# %%
# Importing the dataset

raw_data = pd.read_csv('large_messy_data.csv')

# %%
raw_data.head()
# Out:
#        Name  Age          Salary  Gender Department  Position   Joining Date  \
# 0    grace    25           50000    Male         HR   Manager  April 5, 2018
# 1    david   NaN           65000  Female    Finance  Director     2020/02/20
# 2   hannah    35  SIXTY THOUSAND  Female      Sales  Director     01/15/2020
# 3      eve   NaN           50000  Female         IT   Manager  April 5, 2018
# 4    grace   NaN            NAN   Female    Finance   Manager     01/15/2020
#
#   Performance Score              Email  Phone Number
# 0                 D  email@example.com           NaN
# 1                 F    user@domain.com  123-456-7890
# 2                 C  email@example.com  098-765-4321
# 3                 A   name@company.org
# 4                 F   name@company.org  098-765-4321

# %% [markdown]
# **Data observation**

# %% [markdown]
# The dataset is small and errors could be easily spotted.
#
# From the observation above, the following can be concluded on the current state of the data:
#
# Messy data are found in the  following columns:
# - Age
# - Salary
# - Joining Date
# - Email
# - Phone Number
#
# Issues and resolution request
# - Age: The column contains both numeric and string data types including nan values and this string is a constant 'thirty'
# - Salary: The column also contains both numeric and string data as well as NAN values which is not a standard representation in Python and will need to be replaced with NaN.  The string here is 'SIXTY THOUSAND'
# - Joining Date: This column has inconsistent date format
# - Email: This column has empty cells and nan values
# - Phone Number: This column also has empty cells and nan values
#
#
# Further format
# - Making the Name column data initial caps
# - Removing any leading or trailing spaces

# %%
# Assessing the data types of the column
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1000 non-null   object
#  1   Age                841 non-null    object
#  2   Salary             1000 non-null   object
#  3   Gender             1000 non-null   object
#  4   Department         1000 non-null   object
#  5   Position           1000 non-null   object
#  6   Joining Date       1000 non-null   object
#  7   Performance Score  1000 non-null   object
#  8   Email              610 non-null    object
#  9   Phone Number       815 non-null    object
# dtypes: object(10)
# memory usage: 78.2+ KB

# %% [markdown]
# **1. Getting rid of whitespaces**

# %%
# Function to strip leading and trailing spaces from all elements
def strip_spaces(x):
    if isinstance(x, str):
        return x.strip()
    else:
        return x  # Return unchanged for other types

# Apply the strip_spaces function to every element in the DataFrame
raw_data = raw_data.map(strip_spaces)

# %% [markdown]
# **2. Making changes to the Age column**

# %% [markdown]
# **Steps to adjusting the Age column**
# - First converting the string 'thirty' to the numerical equivalent by simply replacing 'thirty' with 30
# - Adding a new column called 'Age Correction Note' indicating where the age value was included and where no age was included
# - Filling the 'Age' column with the mean Age as a filler where the value content is NaN
# - Converting the 'Age' column to int data type

# %%
# replacing 'thirty' with 30
raw_data['Age'] = raw_data['Age'].replace('thirty', 30)

# creating new column 'Age Correction Note' and filling it up with 'Age No Included' where 'Age' column is 'NaN' and the actual age from 'Age' column
raw_data['Age Correction Note'] = np.where(raw_data['Age'].isnull(), 'Age Not included', raw_data['Age'])

# filling up the 'Age' column with a filler (mean age) where value is 'NaN'
raw_data['Age'] = pd.to_numeric(raw_data['Age'], errors='coerce')   # Converting the Age column to numeric data type necessary to coerce error to NaN

mean_age = raw_data['Age'].mean()
raw_data['Age'] = raw_data['Age'].fillna(mean_age)

# %%
raw_data.head()
# Out:
#      Name        Age          Salary  Gender Department  Position  \
# 0   grace  25.000000           50000    Male         HR   Manager
# 1   david  35.802616           65000  Female    Finance  Director
# 2  hannah  35.000000  SIXTY THOUSAND  Female      Sales  Director
# 3     eve  35.802616           50000  Female         IT   Manager
# 4   grace  35.802616             NAN  Female    Finance   Manager
#
#     Joining Date Performance Score              Email  Phone Number  \
# 0  April 5, 2018                 D  email@example.com           NaN
# 1     2020/02/20                 F    user@domain.com  123-456-7890
# 2     01/15/2020                 C  email@example.com  098-765-4321
# 3  April 5, 2018                 A   name@company.org
# 4     01/15/2020                 F   name@company.org  098-765-4321
#
#   Age Correction Note
# 0                  25
# 1    Age Not included
# 2                  35
# 3    Age Not included
# 4    Age Not included

# %% [markdown]
# convert the 'Age' column to int data type

# %%
raw_data['Age'] = raw_data['Age'].astype(int)

# %%
raw_data.head()
# Out:
#      Name  Age          Salary  Gender Department  Position   Joining Date  \
# 0   grace   25           50000    Male         HR   Manager  April 5, 2018
# 1   david   35           65000  Female    Finance  Director     2020/02/20
# 2  hannah   35  SIXTY THOUSAND  Female      Sales  Director     01/15/2020
# 3     eve   35           50000  Female         IT   Manager  April 5, 2018
# 4   grace   35             NAN  Female    Finance   Manager     01/15/2020
#
#   Performance Score              Email  Phone Number Age Correction Note
# 0                 D  email@example.com           NaN                  25
# 1                 F    user@domain.com  123-456-7890    Age Not included
# 2                 C  email@example.com  098-765-4321                  35
# 3                 A   name@company.org                  Age Not included
# 4                 F   name@company.org  098-765-4321    Age Not included

# %% [markdown]
# **3. Making changes with the Salary column**

# %% [markdown]
# **Steps to adjusting the Age column**
# - First converting the string 'SIXTY THOUSAND' to the numerical equivalent by simply replacing 'SIXTY THOUSAND' with 60000
# - Adding a new column called 'Salary Correction Note' indicating where the salary value was included and where no salary was included
# - Filling the 'Salary' column with the mean Salary as a filler where the value content is NaN
# - Converting the 'Salary' column to int data type (optional)

# %%
# replacing 'SIXTY THOUSAND' with 60000
raw_data['Salary'] = raw_data['Salary'].replace('SIXTY THOUSAND', 60000)

# replacing NAN with NaN
raw_data['Salary'] = raw_data['Salary'].replace('NAN', 'NaN')

# Replace 'NAN' and NaN values in 'Salary' column with 'salary not included'
raw_data['Salary Correction Note'] = np.where(raw_data['Salary'].notnull() & (raw_data['Salary'] != 'NaN'), raw_data['Salary'], 'Salary not included')

# filling up the 'Salary' column with a filler (mean salary) where value is 'NaN'
raw_data['Salary'] = pd.to_numeric(raw_data['Salary'], errors='coerce')   # Converting the Salary column to numeric data type necessary to coerce error to NaN

mean_salary = raw_data['Salary'].mean()
raw_data['Salary'] = raw_data['Salary'].fillna(mean_salary)

# %%
raw_data.head()
# Out:
#      Name  Age        Salary  Gender Department  Position   Joining Date  \
# 0   grace   25  50000.000000    Male         HR   Manager  April 5, 2018
# 1   david   35  65000.000000  Female    Finance  Director     2020/02/20
# 2  hannah   35  60000.000000  Female      Sales  Director     01/15/2020
# 3     eve   35  50000.000000  Female         IT   Manager  April 5, 2018
# 4   grace   35  60216.086435  Female    Finance   Manager     01/15/2020
#
#   Performance Score              Email  Phone Number Age Correction Note  \
# 0                 D  email@example.com           NaN                  25
# 1                 F    user@domain.com  123-456-7890    Age Not included
# 2                 C  email@example.com  098-765-4321                  35
# 3                 A   name@company.org                  Age Not included
# 4                 F   name@company.org  098-765-4321    Age Not included
#
#   Salary Correction Note
# 0                  50000
# 1                  65000
# 2                  60000
# 3                  50000
# 4    Salary not included

# %%
# Format the Salary column to remove trailing zeros
# raw_data['Salary'] =raw_data['Salary'].apply(lambda x: '{:.2f}'.format(x).rstrip('0').rstrip('.'))

def format_salary(x):
    if isinstance(x, float):
        # Convert to string, remove trailing zeros and unnecessary decimal point and use the result to convert back to float
        return '{:.{}f}'.format(x, len(str(x).split('.')[1])).rstrip('0').rstrip('.')
    else:
        return x  # Return as is if not a float

# Apply the function to the Salary column
raw_data['Salary'] = raw_data['Salary'].apply(format_salary)

raw_data.head()
# Out:
#      Name  Age             Salary  Gender Department  Position   Joining Date  \
# 0   grace   25              50000    Male         HR   Manager  April 5, 2018
# 1   david   35              65000  Female    Finance  Director     2020/02/20
# 2  hannah   35              60000  Female      Sales  Director     01/15/2020
# 3     eve   35              50000  Female         IT   Manager  April 5, 2018
# 4   grace   35  60216.08643457383  Female    Finance   Manager     01/15/2020
#
#   Performance Score              Email  Phone Number Age Correction Note  \
# 0                 D  email@example.com           NaN                  25
# 1                 F    user@domain.com  123-456-7890    Age Not included
# 2                 C  email@example.com  098-765-4321                  35
# 3                 A   name@company.org                  Age Not included
# 4                 F   name@company.org  098-765-4321    Age Not included
#
#   Salary Correction Note
# 0                  50000
# 1                  65000
# 2                  60000
# 3                  50000
# 4    Salary not included

# %% [markdown]
# **3. Making changes to the 'Joining Date'  column**

# %%
raw_data['Joining Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Joining Date
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
# deciding a date format; I will use the '%Y-%m-%d' format

# raw_data['Joining Date'] = pd.to_datetime(raw_data['Joining Date'], errors='coerce')

# Define a function to parse and convert dates

from datetime import datetime

def parse_date(date_str):
    formats = ['%B %d, %Y', '%Y/%m/%d', '%m/%d/%Y']
    for fmt in formats:
        try:
            return datetime.strptime(date_str, fmt).strftime('%Y-%m-%d')
        except ValueError:
            continue
    return None  # Return None for invalid dates

# Apply the function to the 'Joining Date' column
raw_data['Joining Date'] = raw_data['Joining Date'].apply(parse_date)

# %%
raw_data.head()
# Out:
#      Name  Age             Salary  Gender Department  Position Joining Date  \
# 0   grace   25              50000    Male         HR   Manager   2018-04-05
# 1   david   35              65000  Female    Finance  Director   2020-02-20
# 2  hannah   35              60000  Female      Sales  Director   2020-01-15
# 3     eve   35              50000  Female         IT   Manager   2018-04-05
# 4   grace   35  60216.08643457383  Female    Finance   Manager   2020-01-15
#
#   Performance Score              Email  Phone Number Age Correction Note  \
# 0                 D  email@example.com           NaN                  25
# 1                 F    user@domain.com  123-456-7890    Age Not included
# 2                 C  email@example.com  098-765-4321                  35
# 3                 A   name@company.org                  Age Not included
# 4                 F   name@company.org  098-765-4321    Age Not included
#
#   Salary Correction Note
# 0                  50000
# 1                  65000
# 2                  60000
# 3                  50000
# 4    Salary not included

# %%
# replacing 'None' with 'Date Inconclusive' on the 'Joining Date' column
raw_data['Joining Date'] = raw_data['Joining Date'].fillna('Date Inconclusive')
raw_data.head()
# Out:
#      Name  Age             Salary  Gender Department  Position Joining Date  \
# 0   grace   25              50000    Male         HR   Manager   2018-04-05
# 1   david   35              65000  Female    Finance  Director   2020-02-20
# 2  hannah   35              60000  Female      Sales  Director   2020-01-15
# 3     eve   35              50000  Female         IT   Manager   2018-04-05
# 4   grace   35  60216.08643457383  Female    Finance   Manager   2020-01-15
#
#   Performance Score              Email  Phone Number Age Correction Note  \
# 0                 D  email@example.com           NaN                  25
# 1                 F    user@domain.com  123-456-7890    Age Not included
# 2                 C  email@example.com  098-765-4321                  35
# 3                 A   name@company.org                  Age Not included
# 4                 F   name@company.org  098-765-4321    Age Not included
#
#   Salary Correction Note
# 0                  50000
# 1                  65000
# 2                  60000
# 3                  50000
# 4    Salary not included

# %% [markdown]
# **4. Making changes to the Email column**

# %%
# replacing NaN in the email column with Email Not Included
raw_data['Email'] = raw_data['Email'].fillna('Email Not Included')

# %%
raw_data.head(10)
# Out:
#       Name  Age             Salary  Gender Department   Position  \
# 0    grace   25              50000    Male         HR    Manager
# 1    david   35              65000  Female    Finance   Director
# 2   hannah   35              60000  Female      Sales   Director
# 3      eve   35              50000  Female         IT    Manager
# 4    grace   35  60216.08643457383  Female    Finance    Manager
# 5     jack   35              65000   Other  Marketing   Director
# 6  charlie   35              50000    Male  Marketing      Clerk
# 7    grace   40              50000   Other         HR   Director
# 8   hannah   40              60000  Female  Marketing    Manager
# 9      eve   30  60216.08643457383   Other    Finance  Assistant
#
#         Joining Date Performance Score               Email  Phone Number  \
# 0         2018-04-05                 D   email@example.com           NaN
# 1         2020-02-20                 F     user@domain.com  123-456-7890
# 2         2020-01-15                 C   email@example.com  098-765-4321
# 3         2018-04-05                 A    name@company.org
# 4         2020-01-15                 F    name@company.org  098-765-4321
# 5  Date Inconclusive                 F     user@domain.com           NaN
# 6  Date Inconclusive                 B  Email Not Included  123-456-7890
# 7  Date Inconclusive                 C  Email Not Included
# 8         2020-01-15                 C     user@domain.com  123-456-7890
# 9         2020-02-20                 A  Email Not Included
#
#   Age Correction Note Salary Correction Note
# 0                  25                  50000
# 1    Age Not included                  65000
# 2                  35                  60000
# 3    Age Not included                  50000
# 4    Age Not included    Salary not included
# 5    Age Not included                  65000
# 6    Age Not included                  50000
# 7                  40                  50000
# 8                  40                  60000
# 9                  30    Salary not included

# %% [markdown]
# **5. Making changes to the Phone Number column**

# %%
raw_data['Phone Number'] = raw_data['Phone Number'].fillna('000-000-0000')
raw_data['Phone Number'] = raw_data['Phone Number'].replace('', '000-000-0000')
raw_data.head(30)
# Out:
#        Name  Age             Salary  Gender Department   Position  \
# 0     grace   25              50000    Male         HR    Manager
# 1     david   35              65000  Female    Finance   Director
# 2    hannah   35              60000  Female      Sales   Director
# 3       eve   35              50000  Female         IT    Manager
# 4     grace   35  60216.08643457383  Female    Finance    Manager
# 5      jack   35              65000   Other  Marketing   Director
# 6   charlie   35              50000    Male  Marketing      Clerk
# 7     grace   40              50000   Other         HR   Director
# 8    hannah   40              60000  Female  Marketing    Manager
# 9       eve   30  60216.08643457383   Other    Finance  Assistant
# 10    david   25              70000    Male  Marketing    Analyst
# 11   hannah   35              70000   Other    Finance  Assistant
# 12   hannah   30              50000    Male         IT  Assistant
# 13  charlie   25              55000   Other         HR    Manager
# 14    frank   50  60216.08643457383    Male  Marketing   Director
# 15      eve   35              65000    Male    Finance      Clerk
# 16      bob   40              55000  Female      Sales  Assistant
# 17   hannah   50              55000    Male         HR   Director
# 18    frank   25  60216.08643457383  Female         IT      Clerk
# 19      bob   50              50000  Female    Finance  Assistant
# 20      eve   35              50000  Female         IT      Clerk
# 21    alice   25              50000   Other         IT   Director
# 22     jack   50              50000   Other  Marketing    Analyst
# 23    frank   40              70000   Other  Marketing   Director
# 24      ivy   40              50000   Other    Finance    Manager
# 25    alice   30              70000    Male      Sales      Clerk
# 26     jack   50              70000    Male    Finance    Analyst
# 27  charlie   35              50000   Other      Sales      Clerk
# 28    grace   50              60000    Male         IT      Clerk
# 29    david   25              65000    Male         HR  Assistant
#
#          Joining Date Performance Score               Email  Phone Number  \
# 0          2018-04-05                 D   email@example.com  000-000-0000
# 1          2020-02-20                 F     user@domain.com  123-456-7890
# 2          2020-01-15                 C   email@example.com  098-765-4321
# 3          2018-04-05                 A    name@company.org  000-000-0000
# 4          2020-01-15                 F    name@company.org  098-765-4321
# 5   Date Inconclusive                 F     user@domain.com  000-000-0000
# 6   Date Inconclusive                 B  Email Not Included  123-456-7890
# 7   Date Inconclusive                 C  Email Not Included  000-000-0000
# 8          2020-01-15                 C     user@domain.com  123-456-7890
# 9          2020-02-20                 A  Email Not Included  000-000-0000
# 10  Date Inconclusive                 B  Email Not Included  123-456-7890
# 11  Date Inconclusive                 A  Email Not Included  000-000-0000
# 12         2018-04-05                 D  Email Not Included  000-000-0000
# 13         2020-02-20                 F  Email Not Included  555-555-5555
# 14  Date Inconclusive                 A  Email Not Included  123-456-7890
# 15         2018-04-05                 F  Email Not Included  123-456-7890
# 16         2020-01-15                 B  Email Not Included  098-765-4321
# 17         2018-04-05                 D     user@domain.com  000-000-0000
# 18  Date Inconclusive                 B   email@example.com  555-555-5555
# 19  Date Inconclusive                 D     user@domain.com  000-000-0000
# 20         2020-01-15                 D   email@example.com  098-765-4321
# 21         2018-04-05                 F     user@domain.com  555-555-5555
# 22         2018-04-05                 B   email@example.com  000-000-0000
# 23         2020-01-15                 B   email@example.com  555-555-5555
# 24         2018-04-05                 A    name@company.org  123-456-7890
# 25         2020-01-15                 B   email@example.com  123-456-7890
# 26         2020-02-20                 A   email@example.com  098-765-4321
# 27  Date Inconclusive                 C    name@company.org  000-000-0000
# 28         2020-02-20                 C  Email Not Included  000-000-0000
# 29  Date Inconclusive                 C  Email Not Included  555-555-5555
#
#    Age Correction Note Salary Correction Note
# 0                   25                  50000
# 1     Age Not included                  65000
# 2                   35                  60000
# 3     Age Not included                  50000
# 4     Age Not included    Salary not included
# 5     Age Not included                  65000
# 6     Age Not included                  50000
# 7                   40                  50000
# 8                   40                  60000
# 9                   30    Salary not included
# 10                  25                  70000
# 11    Age Not included                  70000
# 12                  30                  50000
# 13                  25                  55000
# 14                  50    Salary not included
# 15                  35                  65000
# 16                  40                  55000
# 17                  50                  55000
# 18                  25    Salary not included
# 19                  50                  50000
# 20                  35                  50000
# 21                  25                  50000
# 22                  50                  50000
# 23                  40                  70000
# 24                  40                  50000
# 25                  30                  70000
# 26                  50                  70000
# 27    Age Not included                  50000
# 28                  50                  60000
# 29                  25                  65000

# %% [markdown]
# **6. Making the first letter of the names in the 'Name' column caps**

# %%
def first_letter_caps(name):
    return name.capitalize()

raw_data['Name'] = raw_data['Name'].apply(first_letter_caps)

# %%
raw_data
# Out:
#        Name  Age             Salary  Gender Department   Position  \
# 0     Grace   25              50000    Male         HR    Manager
# 1     David   35              65000  Female    Finance   Director
# 2    Hannah   35              60000  Female      Sales   Director
# 3       Eve   35              50000  Female         IT    Manager
# 4     Grace   35  60216.08643457383  Female    Finance    Manager
# ..      ...  ...                ...     ...        ...        ...
# 995    Jack   50              65000  Female         HR    Manager
# 996    Jack   30              50000    Male    Finance    Analyst
# 997  Hannah   30              70000    Male         IT  Assistant
# 998     Bob   25              65000   Other  Marketing    Manager
# 999     Ivy   30              60000    Male    Finance    Manager
#
#     Joining Date Performance Score               Email  Phone Number  \
# 0     2018-04-05                 D   email@example.com  000-000-0000
# 1     2020-02-20                 F     user@domain.com  123-456-7890
# 2     2020-01-15                 C   email@example.com  098-765-4321
# 3     2018-04-05                 A    name@company.org  000-000-0000
# 4     2020-01-15                 F    name@company.org  098-765-4321
# ..           ...               ...                 ...           ...
# 995   2020-02-20                 F  Email Not Included  098-765-4321
# 996   2018-04-05                 C  Email Not Included  555-555-5555
# 997   2020-01-15                 D     user@domain.com  000-000-0000
# 998   2018-04-05                 D   email@example.com  000-000-0000
# 999   2020-02-20                 C     user@domain.com  123-456-7890
#
#     Age Correction Note Salary Correction Note
# 0                    25                  50000
# 1      Age Not included                  65000
# 2                    35                  60000
# 3      Age Not included                  50000
# 4      Age Not included    Salary not included
# ..                  ...                    ...
# 995                  50                  65000
# 996                  30                  50000
# 997                  30                  70000
# 998                  25                  65000
# 999                  30                  60000
#
# [1000 rows x 12 columns]

# %% [markdown]
# **7. Checking for missing data**

# %%
raw_data.isna()
# Out:
#       Name    Age  Salary  Gender  Department  Position  Joining Date  \
# 0    False  False   False   False       False     False         False
# 1    False  False   False   False       False     False         False
# 2    False  False   False   False       False     False         False
# 3    False  False   False   False       False     False         False
# 4    False  False   False   False       False     False         False
# ..     ...    ...     ...     ...         ...       ...           ...
# 995  False  False   False   False       False     False         False
# 996  False  False   False   False       False     False         False
# 997  False  False   False   False       False     False         False
# 998  False  False   False   False       False     False         False
# 999  False  False   False   False       False     False         False
#
#      Performance Score  Email  Phone Number  Age Correction Note  \
# 0                False  False         False                False
# 1                False  False         False                False
# 2                False  False         False                False
# 3                False  False         False                False
# 4                False  False         False                False
# ..                 ...    ...           ...                  ...
# 995              False  False         False                False
# 996              False  False         False                False
# 997              False  False         False                False
# 998              False  False         False                False
# 999              False  False         False                False
#
#      Salary Correction Note
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 995                   False
# 996                   False
# 997                   False
# 998                   False
# 999                   False
#
# [1000 rows x 12 columns]

# %%
raw_data.isnull().sum()
# Out:
# Name                      0
# Age                       0
# Salary                    0
# Gender                    0
# Department                0
# Position                  0
# Joining Date              0
# Performance Score         0
# Email                     0
# Phone Number              0
# Age Correction Note       0
# Salary Correction Note    0
# dtype: int64

# %% [markdown]
# **8. Final Data**

# %%
Cleaned_Data = raw_data
Cleaned_Data.head(30)
# Out:
#        Name  Age             Salary  Gender Department   Position  \
# 0     Grace   25              50000    Male         HR    Manager
# 1     David   35              65000  Female    Finance   Director
# 2    Hannah   35              60000  Female      Sales   Director
# 3       Eve   35              50000  Female         IT    Manager
# 4     Grace   35  60216.08643457383  Female    Finance    Manager
# 5      Jack   35              65000   Other  Marketing   Director
# 6   Charlie   35              50000    Male  Marketing      Clerk
# 7     Grace   40              50000   Other         HR   Director
# 8    Hannah   40              60000  Female  Marketing    Manager
# 9       Eve   30  60216.08643457383   Other    Finance  Assistant
# 10    David   25              70000    Male  Marketing    Analyst
# 11   Hannah   35              70000   Other    Finance  Assistant
# 12   Hannah   30              50000    Male         IT  Assistant
# 13  Charlie   25              55000   Other         HR    Manager
# 14    Frank   50  60216.08643457383    Male  Marketing   Director
# 15      Eve   35              65000    Male    Finance      Clerk
# 16      Bob   40              55000  Female      Sales  Assistant
# 17   Hannah   50              55000    Male         HR   Director
# 18    Frank   25  60216.08643457383  Female         IT      Clerk
# 19      Bob   50              50000  Female    Finance  Assistant
# 20      Eve   35              50000  Female         IT      Clerk
# 21    Alice   25              50000   Other         IT   Director
# 22     Jack   50              50000   Other  Marketing    Analyst
# 23    Frank   40              70000   Other  Marketing   Director
# 24      Ivy   40              50000   Other    Finance    Manager
# 25    Alice   30              70000    Male      Sales      Clerk
# 26     Jack   50              70000    Male    Finance    Analyst
# 27  Charlie   35              50000   Other      Sales      Clerk
# 28    Grace   50              60000    Male         IT      Clerk
# 29    David   25              65000    Male         HR  Assistant
#
#          Joining Date Performance Score               Email  Phone Number  \
# 0          2018-04-05                 D   email@example.com  000-000-0000
# 1          2020-02-20                 F     user@domain.com  123-456-7890
# 2          2020-01-15                 C   email@example.com  098-765-4321
# 3          2018-04-05                 A    name@company.org  000-000-0000
# 4          2020-01-15                 F    name@company.org  098-765-4321
# 5   Date Inconclusive                 F     user@domain.com  000-000-0000
# 6   Date Inconclusive                 B  Email Not Included  123-456-7890
# 7   Date Inconclusive                 C  Email Not Included  000-000-0000
# 8          2020-01-15                 C     user@domain.com  123-456-7890
# 9          2020-02-20                 A  Email Not Included  000-000-0000
# 10  Date Inconclusive                 B  Email Not Included  123-456-7890
# 11  Date Inconclusive                 A  Email Not Included  000-000-0000
# 12         2018-04-05                 D  Email Not Included  000-000-0000
# 13         2020-02-20                 F  Email Not Included  555-555-5555
# 14  Date Inconclusive                 A  Email Not Included  123-456-7890
# 15         2018-04-05                 F  Email Not Included  123-456-7890
# 16         2020-01-15                 B  Email Not Included  098-765-4321
# 17         2018-04-05                 D     user@domain.com  000-000-0000
# 18  Date Inconclusive                 B   email@example.com  555-555-5555
# 19  Date Inconclusive                 D     user@domain.com  000-000-0000
# 20         2020-01-15                 D   email@example.com  098-765-4321
# 21         2018-04-05                 F     user@domain.com  555-555-5555
# 22         2018-04-05                 B   email@example.com  000-000-0000
# 23         2020-01-15                 B   email@example.com  555-555-5555
# 24         2018-04-05                 A    name@company.org  123-456-7890
# 25         2020-01-15                 B   email@example.com  123-456-7890
# 26         2020-02-20                 A   email@example.com  098-765-4321
# 27  Date Inconclusive                 C    name@company.org  000-000-0000
# 28         2020-02-20                 C  Email Not Included  000-000-0000
# 29  Date Inconclusive                 C  Email Not Included  555-555-5555
#
#    Age Correction Note Salary Correction Note
# 0                   25                  50000
# 1     Age Not included                  65000
# 2                   35                  60000
# 3     Age Not included                  50000
# 4     Age Not included    Salary not included
# 5     Age Not included                  65000
# 6     Age Not included                  50000
# 7                   40                  50000
# 8                   40                  60000
# 9                   30    Salary not included
# 10                  25                  70000
# 11    Age Not included                  70000
# 12                  30                  50000
# 13                  25                  55000
# 14                  50    Salary not included
# 15                  35                  65000
# 16                  40                  55000
# 17                  50                  55000
# 18                  25    Salary not included
# 19                  50                  50000
# 20                  35                  50000
# 21                  25                  50000
# 22                  50                  50000
# 23                  40                  70000
# 24                  40                  50000
# 25                  30                  70000
# 26                  50                  70000
# 27    Age Not included                  50000
# 28                  50                  60000
# 29                  25                  65000

# %% [markdown]
# **Note**
#
# Dealing with a date column having different date formats in messy data as this in its large form could pose some challenges.  Adjusting this kind of column will require shift editing in the sense that you take note of the first ten formats and make changes checking if there is a None or whatever you have used as an invalid date format and taking note of the sections that display such and going back to re-adjust your code until the column is set completely.  For date format where one is unable to tell between the day and the month e.g 2019.12.01, 2019.12.01, it's safe to ask for clarification from the source of the data otherwise you may want to tag it as an inconclusive date or date not valid or something like that, assuming a date format for this date could be misleading.
